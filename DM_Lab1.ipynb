# %%
# Read data and look statistics
import pandas as pd
data = pd.read_csv("Telco Customer Churn.csv")

print("Display all first of 5 rows :")
display(data.head())
print("The shape of data in (nrows,ncols)")
print(data.shape)
# Out:
# Display all first of 5 rows :
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]
# The shape of data in (nrows,ncols)
# (7043, 21)

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
print("How to extract Index of Dataframe ? \n\t", data.index)
print("\nHow to extract Column of Dataframe in the list type ? \n\t", list(data.columns))
print("\nHow many InternetService are there in the data ? \n\t", data["InternetService"].unique())
print(f"\nWhat is min max value of Tenure in the data ? \n\t  \
      from min : {np.min(data['tenure'])} to max : {np.max(data['tenure'])}")
print(f"\nWhat is mean std value of Monthly Charges in the data ? \n\t  \
      mean : {round(data['MonthlyCharges'].mean(), 3)} \n\t\tstd : {round(data['MonthlyCharges'].std(), 3)}")
print(f"\nWhat is sum and median value of Monthly Charges in the data ? \n\t  \
      sum : {data['MonthlyCharges'].sum()} \n\t\tmedian : {data['MonthlyCharges'].median()}")
# Out:
# How to extract Index of Dataframe ?
# 	 RangeIndex(start=0, stop=7043, step=1)
#
# How to extract Column of Dataframe in the list type ?
# 	 ['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure', 'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn']
#
# How many InternetService are there in the data ?
# 	 ['DSL' 'Fiber optic' 'No']
#
# What is min max value of Tenure in the data ?
# 	        from min : 0 to max : 72
#
# What is mean std value of Monthly Charges in the data ?
# 	        mean : 64.762
# 		std : 30.09
#
# What is sum and median value of Monthly Charges in the data ?
# 	        sum : 456116.6
# 		median : 70.35

# %%
print("How many cases of Churn ?")
print(data["Churn"].value_counts())
print("\n")

print("Can we see the statistics table of the whole data ?")
display(data.describe())
print("\n")

print("Is there any missing value at all columns ?")
display(data.isnull().sum())
print("\n")
# Out:
# How many cases of Churn ?
# No     5174
# Yes    1869
# Name: Churn, dtype: int64
#
#
# Can we see the statistics table of the whole data ?
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000
# Is there any missing value at all columns ?
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
print("How many Payment Method are there in the table ?")
print(len(data["PaymentMethod"].unique()))
print("\n")

print("How we can get only the rows from index 10 to 15 ?")
display(data.loc[10:15, :])
print("\n")

print("How we can reset index of the above results in a new table ? ")
df = data.loc[10:15, :]
df = df.reset_index(drop = True)
display(df)
print("\n")

print("How we can get the rows from index 10 to 15 of columns State, Areacode, International plan and Churn ?")
display(data.loc[10:15, ["customerID", "tenure", "InternetService", "Churn"]])
print("\n")

print("How we can get only the rows from index 10 of columns State, Areacode, International plan and Churn ?")
display(data.loc[10, ["customerID", "tenure", "InternetService", "Churn"]])
# Out:
# How many Payment Method are there in the table ?
# 4
#
#
# How we can get only the rows from index 10 to 15 ?
#     customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 10  9763-GRSKD    Male              0     Yes        Yes      13          Yes
# 11  7469-LKBCI    Male              0      No         No      16          Yes
# 12  8091-TTVAX    Male              0     Yes         No      58          Yes
# 13  0280-XJGEX    Male              0      No         No      49          Yes
# 14  5129-JLPIS    Male              0      No         No      25          Yes
# 15  3655-SNQYZ  Female              0     Yes        Yes      69          Yes
#
#    MultipleLines InternetService       OnlineSecurity  ...  \
# 10            No             DSL                  Yes  ...
# 11            No              No  No internet service  ...
# 12           Yes     Fiber optic                   No  ...
# 13           Yes     Fiber optic                   No  ...
# 14            No     Fiber optic                  Yes  ...
# 15           Yes     Fiber optic                  Yes  ...
#
#        DeviceProtection          TechSupport          StreamingTV  \
# 10                   No                   No                   No
# 11  No internet service  No internet service  No internet service
# 12                  Yes                   No                  Yes
# 13                  Yes                   No                  Yes
# 14                  Yes                  Yes                  Yes
# 15                  Yes                  Yes                  Yes
#
#         StreamingMovies        Contract PaperlessBilling  \
# 10                   No  Month-to-month              Yes
# 11  No internet service        Two year               No
# 12                  Yes        One year               No
# 13                  Yes  Month-to-month              Yes
# 14                  Yes  Month-to-month              Yes
# 15                  Yes        Two year               No
#
#                 PaymentMethod MonthlyCharges  TotalCharges Churn
# 10               Mailed check          49.95        587.45    No
# 11    Credit card (automatic)          18.95         326.8    No
# 12    Credit card (automatic)         100.35        5681.1    No
# 13  Bank transfer (automatic)         103.70        5036.3   Yes
# 14           Electronic check         105.50       2686.05    No
# 15    Credit card (automatic)         113.25       7895.15    No
#
# [6 rows x 21 columns]
# How we can reset index of the above results in a new table ?
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  9763-GRSKD    Male              0     Yes        Yes      13          Yes
# 1  7469-LKBCI    Male              0      No         No      16          Yes
# 2  8091-TTVAX    Male              0     Yes         No      58          Yes
# 3  0280-XJGEX    Male              0      No         No      49          Yes
# 4  5129-JLPIS    Male              0      No         No      25          Yes
# 5  3655-SNQYZ  Female              0     Yes        Yes      69          Yes
#
#   MultipleLines InternetService       OnlineSecurity  ...  \
# 0            No             DSL                  Yes  ...
# 1            No              No  No internet service  ...
# 2           Yes     Fiber optic                   No  ...
# 3           Yes     Fiber optic                   No  ...
# 4            No     Fiber optic                  Yes  ...
# 5           Yes     Fiber optic                  Yes  ...
#
#       DeviceProtection          TechSupport          StreamingTV  \
# 0                   No                   No                   No
# 1  No internet service  No internet service  No internet service
# 2                  Yes                   No                  Yes
# 3                  Yes                   No                  Yes
# 4                  Yes                  Yes                  Yes
# 5                  Yes                  Yes                  Yes
#
#        StreamingMovies        Contract PaperlessBilling  \
# 0                   No  Month-to-month              Yes
# 1  No internet service        Two year               No
# 2                  Yes        One year               No
# 3                  Yes  Month-to-month              Yes
# 4                  Yes  Month-to-month              Yes
# 5                  Yes        Two year               No
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0               Mailed check          49.95        587.45    No
# 1    Credit card (automatic)          18.95         326.8    No
# 2    Credit card (automatic)         100.35        5681.1    No
# 3  Bank transfer (automatic)         103.70        5036.3   Yes
# 4           Electronic check         105.50       2686.05    No
# 5    Credit card (automatic)         113.25       7895.15    No
#
# [6 rows x 21 columns]
# How we can get the rows from index 10 to 15 of columns State, Areacode, International plan and Churn ?
#     customerID  tenure InternetService Churn
# 10  9763-GRSKD      13             DSL    No
# 11  7469-LKBCI      16              No    No
# 12  8091-TTVAX      58     Fiber optic    No
# 13  0280-XJGEX      49     Fiber optic   Yes
# 14  5129-JLPIS      25     Fiber optic    No
# 15  3655-SNQYZ      69     Fiber optic    No
# How we can get only the rows from index 10 of columns State, Areacode, International plan and Churn ?
# customerID         9763-GRSKD
# tenure                     13
# InternetService           DSL
# Churn                      No
# Name: 10, dtype: object

# %%
data = pd.read_csv("Telco Customer Churn.csv")

print("How we can see the type of all columns in data ?")
display(data.info())
print("\n")

print("How we can change Senior Citizen from int64 to object")
print("Original Type of SeniorCitizen :", data["SeniorCitizen"].dtypes)
data["SeniorCitizen"] = data["SeniorCitizen"].astype(str)
print("New Type of Senior Citizen :", data["SeniorCitizen"].dtypes)
print("\n")

print("How we can extract the categorical and numeric columns ?")
CatFeatures = [col for col in data.columns if data[col].dtypes in ["object", "bool"]]
NumFeatures = [col for col in data.columns if data[col].dtypes in ["int64", "float64"]]
print("Categorical Features :", CatFeatures)
print("Numeric Features :", NumFeatures)
print("\n")

print("How we can show the all statistics of Numeric Features ?")
display(data.describe())
print("\n")

print("How we can show the all statistics of Categorical Features ?")
display(data[CatFeatures].describe(include='all'))
print("\n")

print("How we can get data from describe table ?")
NumStats = data[NumFeatures].describe(include='all')
CatStats = data[CatFeatures].describe(include='all')

MonthlyCharges_50 = NumStats.loc["50%", "MonthlyCharges"]
Churn_top_freq = CatStats.loc[["top", "freq"], "Churn"]
print("Monthly Charges at 50 %(median) : \n", MonthlyCharges_50)
print("Top and Frequency of Top in Churn : \n", Churn_top_freq)
# Out:
# How we can see the type of all columns in data ?
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
#  16  PaperlessBilling  7043 non-null   object
#  17  PaymentMethod     7043 non-null   object
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7043 non-null   object
#  20  Churn             7043 non-null   object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 1.1+ MB
# None
# How we can change Senior Citizen from int64 to object
# Original Type of SeniorCitizen : int64
# New Type of Senior Citizen : object
#
#
# How we can extract the categorical and numeric columns ?
# Categorical Features : ['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod', 'TotalCharges', 'Churn']
# Numeric Features : ['tenure', 'MonthlyCharges']
#
#
# How we can show the all statistics of Numeric Features ?
#             tenure  MonthlyCharges
# count  7043.000000     7043.000000
# mean     32.371149       64.761692
# std      24.559481       30.090047
# min       0.000000       18.250000
# 25%       9.000000       35.500000
# 50%      29.000000       70.350000
# 75%      55.000000       89.850000
# max      72.000000      118.750000
# How we can show the all statistics of Categorical Features ?
#         customerID gender SeniorCitizen Partner Dependents PhoneService  \
# count         7043   7043          7043    7043       7043         7043
# unique        7043      2             2       2          2            2
# top     7590-VHVEG   Male             0      No         No          Yes
# freq             1   3555          5901    3641       4933         6361
#
#        MultipleLines InternetService OnlineSecurity OnlineBackup  \
# count           7043            7043           7043         7043
# unique             3               3              3            3
# top               No     Fiber optic             No           No
# freq            3390            3096           3498         3088
#
#        DeviceProtection TechSupport StreamingTV StreamingMovies  \
# count              7043        7043        7043            7043
# unique                3           3           3               3
# top                  No          No          No              No
# freq               3095        3473        2810            2785
#
#               Contract PaperlessBilling     PaymentMethod TotalCharges Churn
# count             7043             7043              7043         7043  7043
# unique               3                2                 4         6531     2
# top     Month-to-month              Yes  Electronic check                 No
# freq              3875             4171              2365           11  5174
# How we can get data from describe table ?
# Monthly Charges at 50 %(median) :
#  70.35
# Top and Frequency of Top in Churn :
#  top       No
# freq    5174
# Name: Churn, dtype: object

# %%
data = pd.read_csv("Telco Customer Churn.csv")

print("How we can draw chart for a numeric features ?")
feature = "tenure"
f, (ax_box, ax_hist) = plt.subplots(2, sharex=True, gridspec_kw={"height_ratios": (.15, .85)})
f.set_figheight(3)
f.set_figwidth(15)
sns.boxplot(data[feature], ax=ax_box)
sns.histplot(data=data, x=feature, ax=ax_hist)
plt.grid()
plt.show()


print("How we can map True/False to Yes/No in Churn feature ?")
MapDict = {"Yes" : "Yes", "No": "No"}
data["Churn_Or_Not"] = data["Churn"].map(MapDict)
display(data.head())

print("How we can draw chart for a numeric feature according to a categorical feature ?")
feature = "tenure"
plt.figure(figsize = (15,3))
sns.boxplot(y = 'Churn_Or_Not', x = feature, data = data)
plt.title(feature)
plt.grid()
plt.show()

print("How we can draw chart for two numeric features according to a categorical feature ?")
plt.figure(figsize=(15,5))
feature_x = "MonthlyCharges"
feature_y = "tenure"
#feature_hue = "Churn_Or_Not"
sns.jointplot(x = feature_x, y= feature_y, data = data, kind = 'hex')
plt.grid()
plt.show()
# Out:
# How we can draw chart for a numeric features ?
# How we can map True/False to Yes/No in Churn feature ?
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... TechSupport  \
# 0  No phone service             DSL             No  ...          No
# 1                No             DSL            Yes  ...          No
# 2                No             DSL            Yes  ...          No
# 3  No phone service             DSL            Yes  ...         Yes
# 4                No     Fiber optic             No  ...          No
#
#   StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No              No  Month-to-month              Yes
# 1          No              No        One year               No
# 2          No              No  Month-to-month              Yes
# 3          No              No        One year               No
# 4          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges TotalCharges  Churn Churn_Or_Not
# 0           Electronic check          29.85        29.85     No           No
# 1               Mailed check          56.95       1889.5     No           No
# 2               Mailed check          53.85       108.15    Yes          Yes
# 3  Bank transfer (automatic)          42.30      1840.75     No           No
# 4           Electronic check          70.70       151.65    Yes          Yes
#
# [5 rows x 22 columns]
# How we can draw chart for a numeric feature according to a categorical feature ?
# How we can draw chart for two numeric features according to a categorical feature ?

# %%
data = pd.read_csv("Telco Customer Churn.csv")

print("How we can draw chart for a categorical feature ?")
feature = "Churn"
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
data[feature].value_counts().plot.pie(autopct='%1.1f%%')
plt.subplot(1,2,2)
sns.countplot(data[feature])
plt.show()

print("How we can draw chart for a categorical feature according to another categorical feature ?")
plt.figure(figsize=(15,5))
feature_x = "tenure"
feature_y = "PhoneService"
sns.stripplot(data[feature_x],data[feature_y])
plt.show()
# Out:
# How we can draw chart for a categorical feature ?
# How we can draw chart for a categorical feature according to another categorical feature ?

# %%
data.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
print("How we can split data into many data ? ")
feature_Geo = ['InternetService', 'PaymentMethod']
data_Geo = data[feature_Geo].copy()
display(data_Geo.head())

feature_Reg = ['TechSupport', 'StreamingTV', 'MonthlyCharges']
data_Reg = data[feature_Reg].copy()
display(data_Reg.head())

feature_Geo = list(set(data.columns) - set(feature_Geo) - set(feature_Reg)) + ["Churn"]
data_Trans = data[feature_Geo].copy()
display(data_Trans.head())

print("How we can merge two data into one by cols ? ")
data_Geo_Reg = pd.concat([data_Geo, data_Reg], axis = 1)
display(data_Geo_Reg.head())
# Out:
# How we can split data into many data ?
#   InternetService              PaymentMethod
# 0             DSL           Electronic check
# 1             DSL               Mailed check
# 2             DSL               Mailed check
# 3             DSL  Bank transfer (automatic)
# 4     Fiber optic           Electronic check
#   TechSupport StreamingTV  MonthlyCharges
# 0          No          No           29.85
# 1          No          No           56.95
# 2          No          No           53.85
# 3         Yes          No           42.30
# 4          No          No           70.70
#    gender  SeniorCitizen TotalCharges Partner     MultipleLines  \
# 0  Female              0        29.85     Yes  No phone service
# 1    Male              0       1889.5      No                No
# 2    Male              0       108.15      No                No
# 3    Male              0      1840.75      No  No phone service
# 4  Female              0       151.65      No                No
#
#   OnlineSecurity        Contract  tenure DeviceProtection PhoneService  \
# 0             No  Month-to-month       1               No           No
# 1            Yes        One year      34              Yes          Yes
# 2            Yes  Month-to-month       2               No          Yes
# 3            Yes        One year      45              Yes           No
# 4             No  Month-to-month       2               No          Yes
#
#   StreamingMovies Dependents OnlineBackup  customerID PaperlessBilling Churn  \
# 0              No         No          Yes  7590-VHVEG              Yes    No
# 1              No         No           No  5575-GNVDE               No    No
# 2              No         No          Yes  3668-QPYBK              Yes   Yes
# 3              No         No           No  7795-CFOCW               No    No
# 4              No         No           No  9237-HQITU              Yes   Yes
#
#   Churn
# 0    No
# 1    No
# 2   Yes
# 3    No
# 4   Yes
# How we can merge two data into one by cols ?
#   InternetService              PaymentMethod TechSupport StreamingTV  \
# 0             DSL           Electronic check          No          No
# 1             DSL               Mailed check          No          No
# 2             DSL               Mailed check          No          No
# 3             DSL  Bank transfer (automatic)         Yes          No
# 4     Fiber optic           Electronic check          No          No
#
#    MonthlyCharges
# 0           29.85
# 1           56.95
# 2           53.85
# 3           42.30
# 4           70.70

# %%
data = pd.read_csv("Telco Customer Churn.csv")

print("How we can filter data by condition ?")
Condition1 = data["MonthlyCharges"] > 80
Condition2 = data["PhoneService"] == "Yes"
data_over100_IntlPlan1 = data[Condition1 & Condition2].copy()
display(data_over100_IntlPlan1.head())
print(data_over100_IntlPlan1.shape)

value1, value2 = 70 , "No"
data_less120_IntlPlan2 = data.query("`MonthlyCharges` < @value1 and `PhoneService` == @value2")
display(data_less120_IntlPlan2.head())
print(data_less120_IntlPlan2.shape)

print("How we can merge two data into one by rows ?")
data_merge = pd.concat([data_over100_IntlPlan1, data_less120_IntlPlan2])
display(data_merge.head())
print(data_merge.shape)
# Out:
# How we can filter data by condition ?
#     customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 5   9305-CDSKC  Female              0      No         No       8          Yes
# 6   1452-KIOVK    Male              0      No        Yes      22          Yes
# 8   7892-POOKP  Female              0     Yes         No      28          Yes
# 12  8091-TTVAX    Male              0     Yes         No      58          Yes
# 13  0280-XJGEX    Male              0      No         No      49          Yes
#
#    MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 5            Yes     Fiber optic             No  ...              Yes
# 6            Yes     Fiber optic             No  ...               No
# 8            Yes     Fiber optic             No  ...              Yes
# 12           Yes     Fiber optic             No  ...              Yes
# 13           Yes     Fiber optic             No  ...              Yes
#
#    TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 5           No         Yes             Yes  Month-to-month              Yes
# 6           No         Yes              No  Month-to-month              Yes
# 8          Yes         Yes             Yes  Month-to-month              Yes
# 12          No         Yes             Yes        One year               No
# 13          No         Yes             Yes  Month-to-month              Yes
#
#                 PaymentMethod MonthlyCharges  TotalCharges Churn
# 5            Electronic check          99.65         820.5   Yes
# 6     Credit card (automatic)          89.10        1949.4    No
# 8            Electronic check         104.80       3046.05   Yes
# 12    Credit card (automatic)         100.35        5681.1    No
# 13  Bank transfer (automatic)         103.70        5036.3   Yes
#
# [5 rows x 21 columns]
# (2666, 21)
#     customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0   7590-VHVEG  Female              0     Yes         No       1           No
# 3   7795-CFOCW    Male              0      No         No      45           No
# 7   6713-OKOMC  Female              0      No         No      10           No
# 20  8779-QRDMV    Male              1      No         No       1           No
# 27  8665-UTDHZ    Male              0     Yes        Yes       1           No
#
#        MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0   No phone service             DSL             No  ...               No
# 3   No phone service             DSL            Yes  ...              Yes
# 7   No phone service             DSL            Yes  ...               No
# 20  No phone service             DSL             No  ...              Yes
# 27  No phone service             DSL             No  ...               No
#
#    TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0           No          No              No  Month-to-month              Yes
# 3          Yes          No              No        One year               No
# 7           No          No              No  Month-to-month               No
# 20          No          No             Yes  Month-to-month              Yes
# 27          No          No              No  Month-to-month               No
#
#                 PaymentMethod MonthlyCharges  TotalCharges Churn
# 0            Electronic check          29.85         29.85    No
# 3   Bank transfer (automatic)          42.30       1840.75    No
# 7                Mailed check          29.75         301.9    No
# 20           Electronic check          39.65         39.65   Yes
# 27           Electronic check          30.20          30.2   Yes
#
# [5 rows x 21 columns]
# (682, 21)
# How we can merge two data into one by rows ?
#     customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 5   9305-CDSKC  Female              0      No         No       8          Yes
# 6   1452-KIOVK    Male              0      No        Yes      22          Yes
# 8   7892-POOKP  Female              0     Yes         No      28          Yes
# 12  8091-TTVAX    Male              0     Yes         No      58          Yes
# 13  0280-XJGEX    Male              0      No         No      49          Yes
#
#    MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 5            Yes     Fiber optic             No  ...              Yes
# 6            Yes     Fiber optic             No  ...               No
# 8            Yes     Fiber optic             No  ...              Yes
# 12           Yes     Fiber optic             No  ...              Yes
# 13           Yes     Fiber optic             No  ...              Yes
#
#    TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 5           No         Yes             Yes  Month-to-month              Yes
# 6           No         Yes              No  Month-to-month              Yes
# 8          Yes         Yes             Yes  Month-to-month              Yes
# 12          No         Yes             Yes        One year               No
# 13          No         Yes             Yes  Month-to-month              Yes
#
#                 PaymentMethod MonthlyCharges  TotalCharges Churn
# 5            Electronic check          99.65         820.5   Yes
# 6     Credit card (automatic)          89.10        1949.4    No
# 8            Electronic check         104.80       3046.05   Yes
# 12    Credit card (automatic)         100.35        5681.1    No
# 13  Bank transfer (automatic)         103.70        5036.3   Yes
#
# [5 rows x 21 columns]
# (3348, 21)

# %%
data.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
# Group By DataFrame
data = pd.read_csv("Telco Customer Churn.csv")

print("How we can group by Internet Service and count on Payment Method, sum on Tenure and Average on MonthlyCharges?")
StateDF = pd.DataFrame()
series = data.groupby("InternetService")["PaymentMethod"].count()
StateDF.index  = series.index
StateDF["Count on Payment Method"] = series
StateDF["Sum on Tenure"] = data.groupby("InternetService")["tenure"].sum()
StateDF["Average on Monthly Charges"] = data.groupby("InternetService")["MonthlyCharges"].mean()
display(StateDF.head())


print("How we can join data with InternetServiceDF on the Internet Service (IS) information to create new information about IS")
StateDF["InternetService"] = StateDF.index
StateDF = StateDF.reset_index(drop = True)
display(StateDF.head())
data = pd.merge(data, StateDF, left_on='InternetService', right_on='InternetService')
display(data.head())
# Out:
# How we can group by Internet Service and count on Payment Method, sum on Tenure and Average on MonthlyCharges?
#                  Count on Payment Method  Sum on Tenure  \
# InternetService
# DSL                                 2421          79461
# Fiber optic                         3096         101914
# No                                  1526          46615
#
#                  Average on Monthly Charges
# InternetService
# DSL                               58.102169
# Fiber optic                       91.500129
# No                                21.079194
# How we can apply a function to create a new column Total Calls, Total Minutes and Total Charges
# How we can join data with InternetServiceDF on the Internet Service (IS) information to create new information about IS
#    Count on Payment Method  Sum on Tenure  Average on Monthly Charges  \
# 0                     2421          79461                   58.102169
# 1                     3096         101914                   91.500129
# 2                     1526          46615                   21.079194
#
#   InternetService
# 0             DSL
# 1     Fiber optic
# 2              No
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  6713-OKOMC  Female              0      No         No      10           No
#
#       MultipleLines InternetService OnlineSecurity  ... StreamingMovies  \
# 0  No phone service             DSL             No  ...              No
# 1                No             DSL            Yes  ...              No
# 2                No             DSL            Yes  ...              No
# 3  No phone service             DSL            Yes  ...              No
# 4  No phone service             DSL            Yes  ...              No
#
#          Contract PaperlessBilling              PaymentMethod MonthlyCharges  \
# 0  Month-to-month              Yes           Electronic check          29.85
# 1        One year               No               Mailed check          56.95
# 2  Month-to-month              Yes               Mailed check          53.85
# 3        One year               No  Bank transfer (automatic)          42.30
# 4  Month-to-month               No               Mailed check          29.75
#
#   TotalCharges Churn Count on Payment Method  Sum on Tenure  \
# 0        29.85    No                    2421          79461
# 1       1889.5    No                    2421          79461
# 2       108.15   Yes                    2421          79461
# 3      1840.75    No                    2421          79461
# 4        301.9    No                    2421          79461
#
#   Average on Monthly Charges
# 0                  58.102169
# 1                  58.102169
# 2                  58.102169
# 3                  58.102169
# 4                  58.102169
#
# [5 rows x 24 columns]
